# %% [markdown]
# <a href="https://colab.research.google.com/github/AnPay/Templates/blob/main/matrix_multiplication_2026_04_16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
https://colab.research.google.com/drive/1SAJZHDFsZ9vhC1vl0nlcM7_XkjZ0ci6I?usp=sharing

How we do matrix multiplication?

Multiply m1 by m2.

m1 = [[1, 2, 3], [4, 5, 6]]

m2 = [[2,3], [0,1], [1, 0]]

m1=2x3
m2=3x2
m1@m2= 2x2

1 2 3      2 3
4 5 6      0 1
           1 0

1*2+2*0+3*1 1*3+2*1+3*0
4*2+5*0+6*1 4*3+5*1+6*0

[[5 5],[14 17]]

2 0 1
3 1 0
# Out:
#   File "/tmp/ipykernel_11584/3908042819.py", line 1
#     https://colab.research.google.com/drive/1SAJZHDFsZ9vhC1vl0nlcM7_XkjZ0ci6I?usp=sharing
#                                             ^
# SyntaxError: invalid decimal literal

# %%
def matmul(m1,m2):
  result = [[0 for _ in range(len(m2[0]))] for _ in range(len(m1))]
  for i in range(len(m1)): #2
    for j in range(len(m2[0])):
      for k in range(len(m2)):
        result[i][j]+=m1[i][k]*m2[k][j]

  return result

# %%
m1 = [[1, 2, 3], [4, 5, 6]]

m2 = [[2,3], [0,1], [1, 0]]
ans = matmul(m1,m2)
ans
# Out:
# [[5, 5], [14, 17]]
