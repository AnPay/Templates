# %% [markdown]
# <a href="https://colab.research.google.com/github/AnPay/Templates/blob/main/llm_practice_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LLM Practice Notebook: Transformer Pipeline (With TODOs)
# Fill in the missing parts to understand the full flow.

# %%
import numpy as np

# %% [markdown]
# ## Embedding Layer

# %%
class Embedding:
    def __init__(self, vocab_size, d_model):
        self.weight = np.random.randn(vocab_size, d_model)

    def forward(self, input_ids):
        # TODO: Implement embedding lookup
        pass

# %% [markdown]
# ## Positional Encoding

# %%
def positional_encoding(seq_len, d_model):
    # TODO: Implement sinusoidal positional encoding
    pass

# %% [markdown]
# ## Attention

# %%
def scaled_dot_product_attention(Q, K, V):
    # TODO: Implement attention
    pass

# %% [markdown]
# ## Transformer Block

# %%
class TransformerBlock:
    def __init__(self, d_model):
        self.Wq = np.random.randn(d_model, d_model)
        self.Wk = np.random.randn(d_model, d_model)
        self.Wv = np.random.randn(d_model, d_model)

    def forward(self, x):
        Q = x @ self.Wq
        K = x @ self.Wk
        V = x @ self.Wv

        # TODO: Call attention
        pass

# %% [markdown]
# ## LM Head

# %%
class LMHead:
    def __init__(self, d_model, vocab_size):
        self.weight = np.random.randn(d_model, vocab_size)

    def forward(self, x):
        # TODO: Implement projection
        pass

# %% [markdown]
# ## Softmax

# %%
def softmax(x):
    # TODO: Implement stable softmax
    pass

# %% [markdown]
# ## End-to-End Pipeline

# %%
def run_pipeline(input_ids, vocab_size=1000, d_model=64):
    emb = Embedding(vocab_size, d_model)
    block = TransformerBlock(d_model)
    lm_head = LMHead(d_model, vocab_size)

    x = emb.forward(input_ids)

    # TODO: Add positional encoding

    x = block.forward(x)

    logits = lm_head.forward(x)

    probs = softmax(logits)

    return probs
